# %%
library(lubridate);
library(ncdf4);
#library(ggplot2);
source("./Sandbox/utility.R")
files_dir = "~/Documents/UCB/NREL Work/solar_data/"

# %%
file = paste0(files_dir,"Telemetry/From_Radiant/qc1_fullpow5m.nc")
#nc <- nc_open(file)
#nc <- nc_close(file)

# %%
data = get_netcdf_telemetry_data(file, c(3,8), lubridate::ymd(20180101), lubridate::ymd(20181231), vname = "f");

# %%
all(is.na(data))
# Out:
# [1] FALSE

# %%
dim(data)
# Out:
# [1]      2 105120

# %%
plot(data[1,], type="l")
# Out:
# plot without title

# %%
plot(data[2,], type="l")
# Out:
# plot without title
